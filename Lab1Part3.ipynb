# %%
library('twitteR')
setup_twitter_oauth("XM1ueC09mbhCb4RO8If6z49vv", "jkGaKWtp4t7sWOaOeh3IdcB8MyvKgVSz6YXiQimbL8fmH7WihM", "964206517099655169-DyRPb0kK90jbozCcWNF5J67VG5yhON6", "Wc9ZvPoz88JKXO1VWrG2x4VuEntwo1prOqms4xDf2mNbE")
# Out:
# [1] "Using direct authentication"

# %%
tweet1 <- searchTwitter("flu OR influenza OR #fightflu OR #fluseason OR #flu2018 OR #fluseason", n = 15000, lang = "en")

# %%
df11 <- twListToDF(tweet1)

# %%
users <- lookupUsers(df11$screenName)

# %%
users
# Out:
# $bartonpublish
# [1] "bartonpublish"
#
# $DrEddyClinic
# [1] "DrEddyClinic"
#
# $thecolumbian
# [1] "thecolumbian"
#
# $TheNYevening
# [1] "TheNYevening"
#
# $sen_kelley
# [1] "sen_kelley"
#
# $SteelCity_Burg
# [1] "SteelCity_Burg"
#
# $islandpacket
# [1] "islandpacket"
#
# $`0spfinsib`
# [1] "0spfinsib"
#
# $PeterBa82304711
# [1] "PeterBa82304711"
#
# $kdworley94
# [1] "kdworley94"
#
# $aristolemywig
# [1] "aristolemywig"
#
# $VanderbiltNurse
# [1] "VanderbiltNurse"
#
# $wsyx6
# [1] "wsyx6"
#
# $zoyaroses
# [1] "zoyaroses"
#
# $vlcnz
# [1] "vlcnz"
#
# $frankywong2000
# [1] "frankywong2000"
#
# $kitten_kean
# [1] "kitten_kean"
#
# $julieme0ww
# [1] "julieme0ww"
#
# $BizHustler
# [1] "BizHustler"
#
# $cityfooI
# [1] "cityfooI"
#
# $JulietPatriot
# [1] "JulietPatriot"
#
# $joeynanai
# [1] "joeynanai"
#
# $tiedye_queen22
# [1] "tiedye_queen22"
#
# $riza_ezra
# [1] "riza_ezra"
#
# $TeaBoots
# [1] "TeaBoots"
#
# $najarvg
# [1] "najarvg"
#
# $Brett3505
# [1] "Brett3505"
#
# $Lucasxto
# ...

# %%
usersDF <- twListToDF(users)

# %%
usersDF
# Out:
# Warning message in FUN(X[[i]], ...):
# “input string 7 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 7 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 7 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 7 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 7 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 7 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# ...

# %%
cordlisty=c()
cordlistx=c()


for(i in usersDF$location){
    coords=geocode(i)
    cordlistx=c(cordlistx,coords[1])
    cordlisty=c(cordlisty,coords[2])
}
# Out:
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=USA&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "USA"”Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=DavaoCity/Singapore/Bangkok&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "DavaoCity/Singapore/Bangkok"”Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Vancouver,%20Washington&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "Vancouver, Washington"”Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=New%20York,%20NY&sensor=false
# Warning message:
# “geocode failed with status OVER_QUERY_LIMIT, location = "New York, NY"”Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=stockton%20ca.&sensor=false
# Warning message:
# ...

# %%
library("maps") 
library("ggmap")
library("ggplot2")
library("sp")


df11 <- df11[!(is.na(df11$latitude)) | !(is.na(df11$longitude)),]
states <- map.where("state", df11$lon, df11$lat)
head(sort(table(states), decreasing=TRUE))

final_loc<-(table(states))
final_table<-data.frame(Location=names(final_loc),freq=c(final_loc))
states<-map_data("state")
ggplot() + geom_map(data=states,map=states,aes(x=long,y=lat,map_id = region))+  geom_map(data=final_table,map=states,aes(fill=freq,map_id=Location))+coord_map()
# Out:
# states
#    california  pennsylvania       florida       alabama       arizona
#             4             3             2             1             1
# new york:main
#             1
# Warning message:
# “Ignoring unknown aesthetics: x, y”
# plot without title
